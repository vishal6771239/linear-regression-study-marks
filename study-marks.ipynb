# %%
# Libraries import
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Data load
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([20, 35, 45, 60, 75])

# Model
model = LinearRegression()

# Train model
model.fit(X, y)

# m aur b
print(f"m (slope)     = {model.coef_[0]:.2f}")
print(f"b (intercept) = {model.intercept_:.2f}")

# Predict
y_pred = model.predict(X)
print(f"Predicted     = {y_pred}")

# MSE
mse = mean_squared_error(y, y_pred)
print(f"MSE           = {mse:.2f}")

# 6 hours predict
new = np.array([[6]])
print(f"6 hours marks = {model.predict(new)[0]:.2f}")
# Out:
# m (slope)     = 13.50
# b (intercept) = 6.50
# Predicted     = [20.  33.5 47.  60.5 74. ]
# MSE           = 1.50
# 6 hours marks = 87.50
